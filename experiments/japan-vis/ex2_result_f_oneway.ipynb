# %%
d_names = sorted(["1138-bus", "USpowerGrid", "qh882", "dwt-1005", "poli"])
target_dataset = d_names[4]

# 2, 3はいい感じ

# %%
# import pandas as pd
# from ex_utils.share import ex_path
# import json
# from pprint import pprint


# types = ["empirical", "multi", "single"]

# score_from_a = {
#     "Aが好ましい": 2,
#     "Aが少し好ましい": 1,
#     "変わらない": 0,
#     "Bが少し好ましい": -1,
#     "Bが好ましい": -2,
# }

# df = pd.read_csv(
#     ex_path.joinpath(
#         "data/thesis2023-fuga ノードリンク図の評価実験（回答） - フォームの回答 1 (3).csv"
#     )
# )
# with open(ex_path.joinpath("data/ex2/pictures.json")) as f:
#     pictures_data = json.load(f)

# remove = ["タイムスタンプ", "氏名", "ノードリンク図の評価実験を通してフィードバックがあれば記入してください。"]
# df = df.drop(columns=remove)
# df = df.rename(
#     columns=dict(
#         zip(
#             df.columns,
#             [c.replace(" [どちらが好ましいですか？]", "") for c in df.columns],
#         )
#     )
# )
# results = df

# n = len(results)
# t = len(types)

# %%
# ans_ab = dict(zip(results.index, [{} for _ in range(len(results.index))]))

# for i, row in results.iterrows():
#     d = row.to_dict()
#     results_map = dict(
#         zip(
#             types,
#             [
#                 dict(zip(types, [0, 0, 0])),
#                 dict(zip(types, [0, 0, 0])),
#                 dict(zip(types, [0, 0, 0])),
#             ],
#         )
#     )

#     for uuid in d:
#         ans = d[uuid]
#         target_data = pictures_data[uuid]
#         a = target_data["A"]
#         b = target_data["B"]
#         dataset = target_data["dataset"]

#         score_a = score_from_a[ans]
#         score_b = -score_from_a[ans]
#         # if dataset == '1138-bus' and (a == "empirical" or b == "empirical"):
#         #     print(ans, target_data)

#         if dataset == target_dataset:
#             results_map[a][b] += score_a
#             results_map[b][a] += score_b
#     ans_ab[i] = results_map

# # n_seed = 3
# # n_compare = 2
# # for key in ans_ab:
# #     for a in types:
# #         for b in types:
# #             ans_ab[key][a][b] /= n_seed * n_compare

# ans_all = dict(
#     zip(
#         types,
#         [
#             dict(zip(types, [0, 0, 0])),
#             dict(zip(types, [0, 0, 0])),
#             dict(zip(types, [0, 0, 0])),
#         ],
#     )
# )
# for key in ans_ab:
#     for a in types:
#         for b in types:
#             ans_all[a][b] += ans_ab[key][a][b]

# %%
# ans_a = {}
# for key in ans_ab:
#     ans_a[key] = {}
#     for a in types:
#         ans_a[key][a] = 0
#         for b in types:
#             ans_a[key][a] += ans_ab[key][a][b]

# %%
# from scipy import stats

# empirical = pd.Series([ans_a[key]["empirical"] for key in ans_a])
# multi = pd.Series([ans_a[key]["multi"] for key in ans_a])
# single = pd.Series([ans_a[key]["single"] for key in ans_a])

# stats.f_oneway(empirical, multi, single)
# Out:
# F_onewayResult(statistic=4.487661574618096, pvalue=0.01712676579544819)

# %%
from statsmodels.formula.api import ols
import statsmodels
import statsmodels.api as sm


import pandas as pd
from ex_utils.share import ex_path
import json
from pprint import pprint

d_names = sorted(["1138-bus", "USpowerGrid", "qh882", "dwt-1005", "poli"])


for target_dataset in d_names:
    types = ["empirical", "multi", "single"]

    score_from_a = {
        "Aが好ましい": 2,
        "Aが少し好ましい": 1,
        "変わらない": 0,
        "Bが少し好ましい": -1,
        "Bが好ましい": -2,
    }

    df = pd.read_csv(
        ex_path.joinpath(
            "data/thesis2023-fuga ノードリンク図の評価実験（回答） - フォームの回答 1 (3).csv"
        )
    )
    with open(ex_path.joinpath("data/ex2/pictures.json")) as f:
        pictures_data = json.load(f)

    remove = ["タイムスタンプ", "氏名", "ノードリンク図の評価実験を通してフィードバックがあれば記入してください。"]
    df = df.drop(columns=remove)
    df = df.rename(
        columns=dict(
            zip(
                df.columns,
                [c.replace(" [どちらが好ましいですか？]", "") for c in df.columns],
            )
        )
    )
    results = df

    n = len(results)
    t = len(types)

    ans_ab = dict(zip(results.index, [{} for _ in range(len(results.index))]))

    for i, row in results.iterrows():
        d = row.to_dict()
        results_map = dict(
            zip(
                types,
                [
                    dict(zip(types, [0, 0, 0])),
                    dict(zip(types, [0, 0, 0])),
                    dict(zip(types, [0, 0, 0])),
                ],
            )
        )

        for uuid in d:
            ans = d[uuid]
            target_data = pictures_data[uuid]
            a = target_data["A"]
            b = target_data["B"]
            dataset = target_data["dataset"]

            score_a = score_from_a[ans]
            score_b = -score_from_a[ans]
            # if dataset == '1138-bus' and (a == "empirical" or b == "empirical"):
            #     print(ans, target_data)

            if dataset == target_dataset:
                results_map[a][b] += score_a
                results_map[b][a] += score_b
        ans_ab[i] = results_map

    # n_seed = 3
    # n_compare = 2
    # for key in ans_ab:
    #     for a in types:
    #         for b in types:
    #             ans_ab[key][a][b] /= n_seed * n_compare

    ans_all = dict(
        zip(
            types,
            [
                dict(zip(types, [0, 0, 0])),
                dict(zip(types, [0, 0, 0])),
                dict(zip(types, [0, 0, 0])),
            ],
        )
    )
    for key in ans_ab:
        for a in types:
            for b in types:
                ans_all[a][b] += ans_ab[key][a][b]

    ans_a = {}
    for key in ans_ab:
        ans_a[key] = {}
        for a in types:
            ans_a[key][a] = 0
            for b in types:
                ans_a[key][a] += ans_ab[key][a][b]

    empirical = pd.Series([ans_a[key]["empirical"] for key in ans_a])
    multi = pd.Series([ans_a[key]["multi"] for key in ans_a])
    single = pd.Series([ans_a[key]["single"] for key in ans_a])

    df = pd.DataFrame(
        {
            "types": ["empirical" for _ in range(len(empirical))]
            + ["multi" for _ in range(len(multi))]
            + ["single" for _ in range(len(single))],
            "score": pd.concat([empirical, multi, single]),
        }
    )

    # anova = ols("score ~ types", data=df).fit()
    # table = sm.stats.anova_lm(anova, typ=2)
    # display(table)

    print(target_dataset)
    print(statsmodels.stats.multicomp.pairwise_tukeyhsd(df.score, df.types))
    print()
# Out:
# 1138-bus
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#   group1  group2 meandiff p-adj   lower  upper  reject
# ------------------------------------------------------
# empirical  multi   4.0667  0.082 -0.4149 8.5482  False
# empirical single  -0.0667 0.9993 -4.5482 4.4149  False
#     multi single  -4.1333 0.0759 -8.6149 0.3482  False
# ------------------------------------------------------
#
# USpowerGrid
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#   group1  group2 meandiff p-adj   lower  upper  reject
# ------------------------------------------------------
# empirical  multi   3.3333  0.199 -1.2947 7.9614  False
# empirical single   0.2667 0.9893 -4.3614 4.8947  False
#     multi single  -3.0667 0.2527 -7.6947 1.5614  False
# ------------------------------------------------------
#
# dwt-1005
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#   group1  group2 meandiff p-adj  lower   upper  reject
# ------------------------------------------------------
# empirical  multi      8.0    0.0 5.2636 10.7364   True
# empirical single     10.8    0.0 8.0636 13.5364   True
#     multi single      2.8 0.0439 0.0636  5.5364   True
# ------------------------------------------------------
#
# poli
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#   group1  group2 meandiff p-adj   lower   upper  reject
# -------------------------------------------------------
# empirical  multi     -2.8 0.4864 -8.6903  3.0903  False
# empirical single      3.0 0.4382 -2.8903  8.8903  False
#     multi single      5.8 0.0544 -0.0903 11.6903  False
# -------------------------------------------------------
#
# qh882
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#   group1  group2 meandiff p-adj   lower  upper  reject
# ------------------------------------------------------
# empirical  multi   4.6667 0.0145  0.8088 8.5245   True
# empirical single   3.1333 0.1314 -0.7245 6.9912  False
#     multi single  -1.5333 0.6024 -5.3912 2.3245  False
# ------------------------------------------------------

# %%
ans_all = {}
for a in types:
    ans_all[a] = 0
    for key in ans_a:
            ans_all[key][]
# Out:
# {0: {'empirical': 5, 'multi': 2, 'single': -7},
#  1: {'empirical': -10, 'multi': 1, 'single': 9},
#  2: {'empirical': -3, 'multi': 1, 'single': 2},
#  3: {'empirical': 4, 'multi': 2, 'single': -6},
#  4: {'empirical': -7, 'multi': 8, 'single': -1},
#  5: {'empirical': -3, 'multi': 3, 'single': 0},
#  6: {'empirical': -4, 'multi': 4, 'single': 0},
#  7: {'empirical': -1, 'multi': 1, 'single': 0},
#  8: {'empirical': 5, 'multi': 0, 'single': -5},
#  9: {'empirical': 1, 'multi': -5, 'single': 4},
#  10: {'empirical': 2, 'multi': 1, 'single': -3},
#  11: {'empirical': -8, 'multi': 4, 'single': 4},
#  12: {'empirical': -4, 'multi': 2, 'single': 2},
#  13: {'empirical': -8, 'multi': 7, 'single': 1},
#  14: {'empirical': -8, 'multi': 0, 'single': 8}}

# %%
x_it = {}
x_it2 = {}
for key in ans_ab:
    x_it[key] = {}
    x_it2[key] = {}
    for type in types:
        x_it[key][type] = 0
        for b in types:
            x_it[key][type] += ans_ab[key][type][b]
        x_it2[key][type] = x_it[key][type] ** 2

x_i = {}
x_i2 = {}
for type in types:
    x_i[type] = 0
    for key in ans_ab:
        x_i[type] += x_it[key][type]
    x_i2[type] = x_i[type] ** 2

# %%
a_i = {}
for type in types:
    a_i[type] = x_i[type] / (t * n)

a_it = {}
for key in ans_ab:
    a_it[key] = {}
    for type in types:
        a_it[key][type] = x_it[key][type] / t - a_i[type]


r_it = {}
for type in types:
    r_it[type] = {}
    for b in types:
        r_it[type][b] = (ans_all[type][b] / n) - (a_i[type] - a_i[b])

# %%
x_i2_sum = sum([x_i2[type] for type in types])

# %%
x_it2
# Out:
# {0: {'empirical': 25, 'multi': 4, 'single': 49},
#  1: {'empirical': 100, 'multi': 1, 'single': 81},
#  2: {'empirical': 9, 'multi': 1, 'single': 4},
#  3: {'empirical': 16, 'multi': 4, 'single': 36},
#  4: {'empirical': 49, 'multi': 64, 'single': 1},
#  5: {'empirical': 9, 'multi': 9, 'single': 0},
#  6: {'empirical': 16, 'multi': 16, 'single': 0},
#  7: {'empirical': 1, 'multi': 1, 'single': 0},
#  8: {'empirical': 25, 'multi': 0, 'single': 25},
#  9: {'empirical': 1, 'multi': 25, 'single': 16},
#  10: {'empirical': 4, 'multi': 1, 'single': 9},
#  11: {'empirical': 64, 'multi': 16, 'single': 16},
#  12: {'empirical': 16, 'multi': 4, 'single': 4},
#  13: {'empirical': 64, 'multi': 49, 'single': 1},
#  14: {'empirical': 64, 'multi': 0, 'single': 64}}

# %%
sa = x_i2_sum / (t * n)

sb = 0
for key in ans_ab:
    sb += sum([x_it2[key][type] for type in types])
sb /= t
sb -= sa

sr = 0
for key in ans_ab:
    for i, type in enumerate(types):
        for b in types[i:]:
            sr += ans_all[type][b]
sr /= n
sr -= sa

# %%
# d_names = sorted(["1138-bus", "USpowerGrid", "qh882", "dwt-1005", "poli"])
# types = ["empirical", "multi", "single"]

# result = dict(
#     zip(
#         d_names,
#         [
#             dict(
#                 zip(
#                     types,
#                     [
#                         dict(zip(types, [0, 0, 0])),
#                         dict(zip(types, [0, 0, 0])),
#                         dict(zip(types, [0, 0, 0])),
#                     ],
#                 )
#             )
#             for _ in range(len(d_names))
#         ],
#     )
# )

# result["all"] = {
#     "empirical": {"empirical": 0, "multi": 0, "single": 0},
#     "multi": {"empirical": 0, "multi": 0, "single": 0},
#     "single": {"empirical": 0, "multi": 0, "single": 0},
# }
# score = dict(
#     zip(
#         d_names,
#         [
#             dict(zip(types, [0, 0, 0])),
#             dict(zip(types, [0, 0, 0])),
#             dict(zip(types, [0, 0, 0])),
#             dict(zip(types, [0, 0, 0])),
#             dict(zip(types, [0, 0, 0])),
#         ],
#     )
# )
# score_all = dict(zip(types, [0, 0, 0]))


# score_from_a = {
#     "Aが好ましい": 2,
#     "Aが少し好ましい": 1,
#     "変わらない": 0,
#     "Bが少し好ましい": -1,
#     "Bが好ましい": -2,
# }
# n = len(res) * 3
# for i, row in res.iterrows():
#     d = row.to_dict()
#     for uuid in d:
#         ans = d[uuid]
#         target_data = data[uuid]
#         a = target_data["A"]
#         b = target_data["B"]
#         dataset = target_data["dataset"]

#         score_a = score_from_a[ans]
#         score_b = -score_from_a[ans]
#         result[dataset][a][b] += score_a
#         result[dataset][b][a] += score_b
#         result["all"][a][b] += score_a
#         result["all"][b][a] += score_b
#         score[dataset][a] += score_a
#         score[dataset][b] += score_b
#         score_all[a] += score_a
#         score_all[b] += score_b

# for d_name in d_names:
#     for a in types:
#         for b in types:
#             result[d_name][a][b] /= n

# for a in types:
#     for b in types:
#         result["all"][a][b] /= n * 5
